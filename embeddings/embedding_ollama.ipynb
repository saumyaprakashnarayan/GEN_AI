# %% [markdown]
# from langchain_community.embeddings

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings=(
    OllamaEmbeddings(model="llama3")#by default uses llama2
    )

# %%
r1=embeddings.embed_documents(
    [
        "this is first text",
        "this is second text"
    ]
)

# %%
r1[0]

# %%
embeddings.embed_query("which text is first text")
