# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you?")
response

# %%
response.content

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots are remarkable talkers, but it\'s important to understand that they don\'t "talk" in the same way humans do. They are **mimicking** sounds, not necessarily understanding the complex meaning of the words.\n\nHere\'s a breakdown of why parrots talk:\n\n1.  **Social Bonding and Flock Integration:**\n    *   **Natural Instinct:** In the wild, parrots are highly social flock animals. They use a wide range of vocalizations to communicate with each other – identifying flock members, warning of predators, finding food, and maintaining social cohesion.\n    *   **"Becoming Part of the Flock":** When a parrot lives with humans, it perceives its human companions as its "flock." By mimicking human speech, it\'s trying to communicate and integrate with its perceived social group. It\'s their way of trying to "speak your language."\n\n2.  **Attention-Seeking:**\n    *   Parrots are intelligent and crave interaction. If they learn that making certain sounds (like human words) gets them a reaction – a laugh, a treat, a stroke, or even just eye contact – they will repeat those sounds to get attention. This is a powerful form of positive reinforcement.\n\n3.  **Mental Stimulation and Play:**\n    *   Parrots are highly intelligent and need mental stimulation. Learning and practicing sounds can be a form of cognitive enrichment and play for them. They have excellent auditory memory and enjoy exercising this ability.\n\n4.  **Display of Auditory Learning:**\n    *   Parrots have a unique vocal organ called a **syrinx** (the avian equivalent of a larynx) which is incredibly flexible and allows them to produce a wide array of sounds, including remarkably accurate imitations of human speech.\n    *   Their ability to mimic is a testament to their keen hearing and advanced auditory learning capabilities. They can associate specific sounds with contexts (e.g., "hello" when someone enters the room, or "bye-bye" when someone leaves).\n\n**Key Distinction: Mimicry vs. Understanding**\n\nWhile parrots can learn to associate words with certain objects or situations (e.g., saying "cracker" when they want a cracker, or "good morning" in the morning), they don\'t grasp the abstract meaning of language in the way humans do. They are masters of **contextual mimicry**. They learn that saying "Polly want a cracker" often results in a cracker, but they don\'t necessarily understand the grammatical structure or the full semantic meaning of the phrase.\n\nIn essence, parrots talk because they are social, intelligent, and highly skilled at imitating sounds, using this ability to bond with their perceived flock and interact with their environment.'

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI



model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, primarily driven by their **social nature, intelligence, and evolutionary adaptations.** It\'s not just about mimicking sounds; there\'s a deeper purpose behind their vocalizations.\n\nHere\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Communication:** Parrots are highly social creatures that live in flocks in the wild. Vocalizations are crucial for maintaining contact, coordinating activities (like foraging or warning of predators), and strengthening social bonds within the group. Talking, or mimicking sounds, can be an extension of this.\n*   **"Membership" in the Flock:** By mimicking the calls of other parrots in their flock, they signal their belonging and reinforce their social standing. This is especially true for young parrots learning the "language" of their specific group.\n\n**2. Intelligence and Learning:**\n\n*   **Cognitive Abilities:** Parrots are among the most intelligent birds. They possess remarkable problem-solving skills, good memory, and the ability to learn complex behaviors. Talking is a prime example of this cognitive prowess.\n*   **Vocal Learning:** Unlike many birds that have innate vocalizations, parrots are **vocal learners**. This means they learn their vocalizations by listening to and imitating sounds in their environment. This ability is what allows them to pick up human speech.\n\n**3. Mimicry as a Survival Tool (in the Wild):**\n\n*   **Camouflage and Deception:** In their natural habitat, parrots might mimic the sounds of predators or other animals to avoid detection or to lure prey. While this is less direct in the context of human speech, the underlying mechanism of learning and reproducing sounds is present.\n*   **Social Information Gathering:** By mimicking the calls of other species, they might be able to gather information about their surroundings, such as the presence of food or danger.\n\n**4. Attention Seeking and Reinforcement (in Captivity):**\n\n*   **Human Interaction:** In a domestic setting, parrots often learn that making sounds, including human words, gets them attention from their owners. This positive reinforcement (getting a reward like praise, treats, or petting) encourages them to repeat the behavior.\n*   **Boredom and Stimulation:** Parrots are intelligent and can get bored if not stimulated. Talking can be a way for them to entertain themselves and interact with their environment, especially if they lack other outlets for their energy and intelligence.\n\n**5. Individual Personalities and Preferences:**\n\n*   **Not all parrots are equal talkers:** Some species are naturally more inclined to mimic than others (e.g., African Greys, Amazons, Budgies). Even within a species, individual parrots will have different personalities and levels of interest in vocalization.\n*   **Specific Sounds:** Some parrots might be drawn to certain sounds, like doorbells, phones, or even specific words, based on their association with positive experiences or their frequency in their environment.\n\n**In summary, parrots talk because they are:**\n\n*   **Highly social animals** that use vocalizations for communication and bonding.\n*   **Intelligent beings** with the remarkable ability of vocal learning.\n*   **Motivated by attention and reinforcement** in their human environments.\n\nIt\'s important to remember that while parrots can mimic human speech, they don\'t understand the meaning of the words in the same way humans do. However, they can learn to associate certain words or phrases with specific contexts or actions, leading to what appears to be meaningful communication.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed03d-040e-7141-840a-4585afb6bbac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'out ...

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3-32b")
response = model.invoke("Why do parrots talk?")
response

# %%
import os
from langchain_groq import ChatGroq



model = ChatGroq(model="qwen/qwen3-32b")
response = model.invoke("Why do parrots talk?")
response

# %% [markdown]
# Streaming And Batch
# Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)

# %%
model.invoke("Why do parrots have colorful feathers?")

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)

# %% [markdown]
# Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
